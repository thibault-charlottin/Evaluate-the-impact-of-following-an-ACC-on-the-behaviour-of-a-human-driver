# %% [markdown]
# ## Demo noteboook

# %% [markdown]
# This notebook aims at presenting the way the preprocessing works

# %% [markdown]
# first, download the data at https://data.transportation.gov/Automobiles/Third-Generation-Simulation-Data-TGSIM-I-90-I-94-M/6a6e-vfvi/data_preview <br>
# to download it click on "epxort" <br>
# Then place the file within this folder

# %%
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)
import src.read_data as read
import src.add_safety_indicators as safety
import src.detect_LC as LC
import src.add_stimulus_evaluation as stimulus

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
path =  os.getcwd()
path_out = os.getcwd()
file = 'example_cleanned.csv'
df = pd.read_csv('Third_Generation_Simulation_Data__TGSIM__I-90_I-94_Stationary_Trajectories_20250401.csv')

df = df[(df['run_index']==1)&(df['time']<10)] #selecting the first 10 seconds 
df.to_csv(file)
read.clean_data(file, path) #add THW and DHW

# %%
path =  os.getcwd()
path_out = os.getcwd()
df = pd.read_csv('1.csv')
df = LC.detect_lane_change(df) #detect lane changes
df.to_csv('1.csv')
safety.process_file(df,path_out) #add TTC and DRAC
stimulus.add_stimulus_info('1.csv', path_out) #add speeddelta

# %%
df = pd.read_csv('1.csv')
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  id  time     xloc_kf     yloc_kf  lane_kf  \
# 0                0           0  57   8.2  378.572421  211.694280        2
# 1                1          18  58   8.2  372.692546  204.972737        2
# 2                2        2429  89   8.2  355.582800  185.894675        2
# 3                3          88  68   8.2  342.169959  174.079258        2
# 4                4        1064  80   8.2  334.397738  168.224197        2
# ...            ...         ...  ..   ...         ...         ...      ...
# 1447          1193        2372  88   2.6  348.514854  165.790453        5
# 1448          1192         953  76   2.6  373.636411  181.622748        6
# 1449          1195        1023  79   2.7  366.552320  179.353432        5
# 1450          1196        2373  88   2.7  350.150900  167.042945        5
# 1451          1194         954  76   2.7  375.381338  182.964267        6
#
#       speed_kf  acceleration_kf  length_smoothed  ...  index           r  \
# 0      4.71776             1.13             5.39  ...    0.0  433.741336
# 1      3.42752             0.28             5.35  ...   18.0  425.339343
# 2      4.16910            -0.78             6.00  ...  570.0  401.243016
# 3      4.96226             0.23             5.70  ...   69.0  383.906068
# 4      4.31752             1.17             5.10  ...  342.0  374.327701
# ...        ...              ...              ...  ...    ...         ...
# 1447  20.60433            -0.35             5.60  ...  513.0  385.939215
# 1448  22.01009             0.08             5.51  ...  279.0  415.440718
# 1449  20.00205            -0.20             5.52  ...  301.0  408.078739
# 1450  20.56890            -0.67             5.60  ...  514.0  387.954892
# 1451  22.01838            -0.52             5.51  ...  280.0  417.596781
#
#          theta        DHW       THW  level_0  speeddelta  Lane Change started  \
# 0     0.509872        NaN       NaN      0.0         NaN                False
# 1     0.502826   8.930401  2.605499      1.0     1.29024                False
# 2     0.481712  25.626468  6.146763      2.0    -0.74158                False
# 3     0.470624  17.874797  3.602148      3.0    -0.79316                False
# 4     0.466098   9.730835  2.253802      4.0     0.64474                False
# ...        ...        ...       ...      ...         ...                  ...
# 1447  0.444024        NaN       NaN      0.0         NaN                False
# 1448  0.452462        NaN       NaN      0.0         NaN                False
# 1449  0.455050        NaN       NaN      0.0         NaN                False
# 1450  0.445128  20.507430  0.997011      1.0    -0.56685                False
# 1451  0.453524        NaN       NaN      0.0         NaN                False
#
#       Lane Change occurred  Overtake
# 0                    False     False
# 1                    False     False
# 2                    False     False
# 3                    False     False
# 4                    False     False
# ...                    ...       ...
# 1447                 False     False
# 1448                 False     False
# 1449                 False     False
# 1450                 False     False
# 1451                 False     False
#
# [1452 rows x 25 columns]
