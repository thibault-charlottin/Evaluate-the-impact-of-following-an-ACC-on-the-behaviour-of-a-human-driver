# %% [markdown]
# ## Demo noteboook

# %% [markdown]
# This notebook aims at presenting the way the preprocessing works

# %% [markdown]
# first, download the data at https://data.transportation.gov/Automobiles/Third-Generation-Simulation-Data-TGSIM-I-90-I-94-M/6a6e-vfvi/data_preview <br>
# to download it click on "epxort" <br>
# Then place the downloaded file within this folder

# %%
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)
import src.read_data as read
import src.add_safety_indicators as safety
import src.detect_LC as LC
import src.add_stimulus_evaluation as stimulus

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
path =  os.getcwd()
path_out = os.getcwd()
file = 'example_cleanned.csv'
df = pd.read_csv('Third_Generation_Simulation_Data__TGSIM__I-90_I-94_Stationary_Trajectories_20250401.csv')

df = df[(df['run_index']==1)&(df['time']<10)] #selecting the first 10 seconds 
df.to_csv(file)

read.clean_data(file, '') #add THW and DHW
#this last line will export a file name 1.csv

# %%
path =  os.getcwd()
path_out = os.getcwd()
df = pd.read_csv('1.csv')
df = LC.detect_lane_change(df) #detect lane changes
df.to_csv('1.csv')
stimulus.add_stimulus_info('1.csv', '') #add speeddelta
safety.process_file(df,'1.csv') #add TTC and DRAC

# %%
df = pd.read_csv('1.csv')
df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   id  time     xloc_kf  \
# 0                7             7        4251  101   8.2  286.090995
# 1                6             6        1276   82   8.2  303.168355
# 2                5             5        1514   83   8.2  317.393991
# 3                4             4        1064   80   8.2  334.397738
# 4                3             3          88   68   8.2  342.169959
# ...            ...           ...         ...  ...   ...         ...
# 1447          1447          1193        2372   88   2.6  348.514854
# 1448          1448          1192         953   76   2.6  373.636411
# 1449          1450          1196        2373   88   2.7  350.150900
# 1450          1449          1195        1023   79   2.7  366.552320
# 1451          1451          1194         954   76   2.7  375.381338
#
#          yloc_kf  lane_kf  speed_kf  acceleration_kf  ...     theta  \
# 0     130.345338        2   7.46903             0.61  ...  0.427508
# ...
